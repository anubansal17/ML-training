# %%
#using sql in pandas
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
#metrics is confusion matrix used to calculate accuracy

# %%
quality = pd.read_csv('quality.csv')
quality.dtypes
# Out:
# MemberID                  int64
# InpatientDays             int64
# ERVisits                  int64
# OfficeVisits              int64
# Narcotics                 int64
# DaysSinceLastERVisit    float64
# Pain                      int64
# TotalVisits               int64
# ProviderCount             int64
# MedicalClaims             int64
# ClaimLines                int64
# StartedOnCombination       bool
# AcuteDrugGapSmall         int64
# PoorCare                  int64
# dtype: object

# %%
quality
# Out:
#      MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0           1              0         0            18          1
# 1           2              1         1             6          1
# 2           3              0         0             5          3
# 3           4              0         1            19          0
# 4           5              8         2            19          3
# 5           6              2         0             9          2
# 6           7             16         1             8          1
# 7           8              2         0             8          0
# 8           9              2         1             4          3
# 9          10              4         2             0          2
# 10         11              6         5            20          2
# 11         12              0         0             7          4
# 12         13              0         1             3          1
# 13         14              1         1            20          3
# ...

# %%
# we can perform sql on data frames using this library
from pandasql import sqldf

# %%
#* means all columns
sqldf("select * from quality", locals())#select all columns with all rows
# Out:
#      MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0           1              0         0            18          1
# 1           2              1         1             6          1
# 2           3              0         0             5          3
# 3           4              0         1            19          0
# 4           5              8         2            19          3
# 5           6              2         0             9          2
# 6           7             16         1             8          1
# 7           8              2         0             8          0
# 8           9              2         1             4          3
# 9          10              4         2             0          2
# 10         11              6         5            20          2
# 11         12              0         0             7          4
# 12         13              0         1             3          1
# 13         14              1         1            20          3
# ...

# %%
sqldf("select MemberID,InpatientDays from quality", locals())
# Out:
#      MemberID  InpatientDays
# 0           1              0
# 1           2              1
# 2           3              0
# 3           4              0
# 4           5              8
# 5           6              2
# 6           7             16
# 7           8              2
# 8           9              2
# 9          10              4
# 10         11              6
# 11         12              0
# 12         13              0
# 13         14              1
# 14         15              6
# 15         16              0
# 16         17              2
# 17         18              3
# 18         19              0
# 19         20              0
# 20         21              5
# 21         22              0
# 22         23              3
# 23         24              8
# 24         25              0
# 25         26              0
# 26         27              3
# 27         28              0
# 28         29              0
# 29         30             13
# ..        ...            ...
# ...

# %%
sqldf("select * from quality where poorcare=1", locals())#to print only the rows where value of poorcare = 1
# Out:
#     MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0          6              2         0             9          2
# 1          9              2         1             4          3
# 2         18              3         0            20          1
# 3         21              5         4            14          1
# 4         24              8         4             6          2
# 5         28              0         2             3          2
# 6         29              0         0            18         32
# 7         30             13         5            21          6
# 8         35              0         8            46          2
# 9         41              1         0            15          0
# 10        46              0         0            21         25
# 11        47             30         8            31          3
# 12        48              0         1             5          2
# 13        56             12         7            46          0
# ...

# %%
sqldf("select MemberID from quality where poorcare=1", locals())#to print specific column and specific rows
# Out:
#     MemberID
# 0          6
# 1          9
# 2         18
# 3         21
# 4         24
# 5         28
# 6         29
# 7         30
# 8         35
# 9         41
# 10        46
# 11        47
# 12        48
# 13        56
# 14        60
# 15        62
# 16        64
# 17        83
# 18        84
# 19        85
# 20        99
# 21       101
# 22       103
# 23       104
# 24       105
# 25       106
# 26       107
# 27       110
# 28       112
# 29       114
# 30       117
# 31       125
# 32       130

# %%
sqldf("select * from quality where MemberID>100 AND poorcare=1",locals())
# Out:
#     MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0        101              0         0            26          0
# 1        103              3         4            14          1
# 2        104              0         0            16         10
# 3        105              0         0            15         25
# 4        106              2         0            28         59
# 5        107              0         2            25         20
# 6        110              0         0             7         21
# 7        112              1         1            29         40
# 8        114              0         0            14         25
# 9        117              0         0            21         25
# 10       125              0         0            23          0
# 11       130              0         2            14          1
#
#     DaysSinceLastERVisit  Pain  TotalVisits  ProviderCount  MedicalClaims  \
# ...

# %%
sqldf("select * from quality where MemberID>100 OR poorcare=1",locals())
# Out:
#     MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0          6              2         0             9          2
# 1          9              2         1             4          3
# 2         18              3         0            20          1
# 3         21              5         4            14          1
# 4         24              8         4             6          2
# 5         28              0         2             3          2
# 6         29              0         0            18         32
# 7         30             13         5            21          6
# 8         35              0         8            46          2
# 9         41              1         0            15          0
# 10        46              0         0            21         25
# 11        47             30         8            31          3
# 12        48              0         1             5          2
# 13        56             12         7            46          0
# ...

# %%
sqldf("select * from quality limit 5", locals())
# Out:
#    MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0         1              0         0            18          1
# 1         2              1         1             6          1
# 2         3              0         0             5          3
# 3         4              0         1            19          0
# 4         5              8         2            19          3
#
#    DaysSinceLastERVisit  Pain  TotalVisits  ProviderCount  MedicalClaims  \
# 0                 731.0    10           18             21             93
# 1                 411.0     0            8             27             19
# 2                 731.0    10            5             16             27
# 3                 158.0    34           20             14             59
# 4                 449.0    10           29             24             51
#
#    ClaimLines  StartedOnCombination  AcuteDrugGapSmall  PoorCare
# 0         222                     0                  0         0
# ...

# %%
sqldf("select * from quality where poorcare=1",locals())
sqldf("select count(*) from quality where poorcare=1",locals())
# Out:
#    count(*)
# 0        33

# %%
sqldf("select count(MemberID) from quality where poorcare=1", locals())
# Out:
#    count(MemberID)
# 0               33

# %%
sqldf("select max(MemberID) from quality", locals())
# Out:
#    max(MemberID)
# 0            131

# %%
#max,min,avg,mean

# %%
#like keyword
#sqldf("select * from quality where name like'%a'",names())

# %%
#to separate test data from train data, we use sklearnmodelsselection

# %%
qualityTrain, qualityTest = train_test_split(quality, test_size = 0.3,random_state = 88) #here 0.3 implies 30 percent

# %%
qualityTest.dtypes
# Out:
# MemberID                  int64
# InpatientDays             int64
# ERVisits                  int64
# OfficeVisits              int64
# Narcotics                 int64
# DaysSinceLastERVisit    float64
# Pain                      int64
# TotalVisits               int64
# ProviderCount             int64
# MedicalClaims             int64
# ClaimLines                int64
# StartedOnCombination       bool
# AcuteDrugGapSmall         int64
# PoorCare                  int64
# dtype: object

# %%
qualityTrain
# Out:
#      MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 60         61              0         0             7          0
# 111       112              1         1            29         40
# 123       124              5         1            17          0
# 43         44              4         4            19          1
# 57         58              0         0            25         34
# 125       126              0         0             6          0
# 26         27              3         0            12          0
# 9          10              4         2             0          2
# 83         84              1         7            26         46
# 18         19              0         0            14          0
# 103       104              0         0            16         10
# 92         93              0         2            15          0
# 30         31              5         2             2          0
# 55         56             12         7            46          0
# ...

# %%
np.shape(qualityTrain)
# Out:
# (91, 14)

# %%
qualityTest.shape
#np.shape(qualityTest)
# Out:
# (40, 14)

# %%
pd.DataFrame(qualityTrain["PoorCare"].value_counts()).T
# Out:
#            0   1
# PoorCare  71  20

# %%
pd.DataFrame(qualityTest["PoorCare"].value_counts()).T
# Out:
#            0   1
# PoorCare  27  13

# %%
import statsmodels.api as sm
#to find logIt we've imported this module

# %%
QualityLog = sm.Logit.from_formula('PoorCare~OfficeVisits+Narcotics', data=quality).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.444464
#          Iterations 6

# %%
QualityLog.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               PoorCare   No. Observations:                  131
# Model:                          Logit   Df Residuals:                      128
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 18 Jul 2018   Pseudo R-squ.:                  0.2125
# Time:                        00:34:50   Log-Likelihood:                -58.225
# converged:                       True   LL-Null:                       -73.939
#                                         LLR p-value:                 1.497e-07
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.5402      0.450     -5.644      0.000      -3.422      -1.658
# ...

# %%
QualityLog.fittedvalues
# Out:
# 0     -1.301091
# 1     -2.053908
# 2     -1.896850
# 3     -1.348253
# 4     -1.018564
# 5     -1.755807
# 6     -1.928438
# 7     -2.038334
# 8     -1.959584
# 9     -2.320420
# 10    -1.065725
# 11    -1.661484
# 12    -2.242112
# 13    -0.955829
# 14    -0.265747
# 15    -2.038334
# 16    -1.975600
# 17    -1.175622
# 18    -1.661926
# 19    -1.285518
# 20    -1.552030
# 21    -1.865703
# 22    -1.787396
# 23    -1.944011
# 24    -1.552030
# 25    -2.101069
# 26    -1.787396
# 27    -2.132215
# 28     2.105692
# 29    -0.563406
#          ...
# 101   -1.740234
# 102   -1.552030
# 103   -0.437494
# 104    1.148214
# 105    5.700237
# 106    1.226080
# 107   -1.017680
# 108   -1.787396
# 109    0.206752
# 110   -0.924683
# 111    3.674944
# 112   -1.160048
# 113    1.085480
# 114   -0.908226
# 115   -1.802969
# 116    1.524623
# 117   -1.206768
# 118   -0.170982
# 119   -1.975600
# 120   -1.865703
# 121   -2.038334
# 122   -1.991173
# 123   -1.473722
# 124   -1.097314
# ...

# %%
#Predicting the data
predictTrain = QualityLog.predict()

# %%
predictTrain
# Out:
# array([ 0.21398145,  0.11365814,  0.13046543,  0.2061562 ,  0.26530723,
#         0.14731624,  0.12692356,  0.11523645,  0.12351202,  0.08944589,
#         0.25621684,  0.15956287,  0.09603207,  0.27771404,  0.43395139,
#         0.11523645,  0.1217887 ,  0.23584035,  0.15950361,  0.21661243,
#         0.17479329,  0.13403966,  0.14339234,  0.12520784,  0.17479329,
#         0.10899296,  0.14339234,  0.10600486,  0.89145518,  0.36275979,
#         0.08205539,  0.57024475,  0.10304834,  0.13409097,  0.63769575,
#         0.50019115,  0.1217887 ,  0.12013284,  0.18402754,  0.11523645,
#         0.16809466,  0.1217887 ,  0.07308681,  0.22472222,  0.1512718 ,
#         0.82121816,  0.43395139,  0.11849645,  0.08205539,  0.13774878,
#         0.16809466,  0.31353587,  0.19607838,  0.10899296,  0.10899296,
#         0.58554642,  0.12865934,  0.94073415,  0.67694681,  0.22202066,
#         0.10899296,  0.82810071,  0.23584035,  0.1512718 ,  0.22472222,
# ...

# %%
#do same for 3 variables and for all variab
lrg_2 = sm.Logit.from_formula('PoorCare~OfficeVisits+Narcotics+ProviderCount', data=quality).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.443563
#          Iterations 6

# %%
lrg_2.fittedvalues
# Out:
# 0     -1.345767
# 1     -1.992458
# 2     -1.934589
# 3     -1.460898
# 4     -1.041573
# 5     -1.587874
# 6     -1.949329
# 7     -2.132206
# 8     -1.882264
# 9     -2.289941
# 10    -1.138233
# 11    -1.782472
# 12    -2.297291
# 13    -1.038481
# 14    -0.302521
# 15    -2.187622
# 16    -1.972100
# 17    -1.265693
# 18    -1.771916
# 19    -1.282320
# 20    -1.524386
# 21    -1.955473
# 22    -1.778100
# 23    -1.809581
# 24    -1.607511
# 25    -2.061409
# 26    -1.768864
# 27    -2.123650
# 28     2.568552
# 29    -0.486758
#          ...
# 101   -1.773802
# 102   -1.385844
# 103   -0.491130
# 104    1.038999
# 105    5.671455
# 106    1.273108
# 107   -1.007269
# 108   -1.815045
# 109    0.218100
# 110   -0.800754
# 111    3.659194
# 112   -1.229954
# 113    0.971254
# 114   -0.795364
# 115   -1.906200
# 116    1.325401
# 117   -0.986198
# 118   -0.165938
# 119   -1.990572
# 120   -1.872348
# 121   -1.938247
# 122   -1.961657
# 123   -1.522500
# 124   -1.042140
# ...
